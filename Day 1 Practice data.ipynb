# %% [markdown]
# Create simple **DataFrame**

# %%
# Create simple DataFrame
data = [("iPhone", 999), ("Samsung", 799), ("MacBook", 1299)]
df = spark.createDataFrame(data, ["product", "price"])
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>price</th></tr></thead><tbody><tr><td>iPhone</td><td>999</td></tr><tr><td>Samsung</td><td>799</td></tr><tr><td>MacBook</td><td>1299</td></tr></tbody></table></div>

# %% [markdown]
# **Filter expensive products**

# %%
df.filter(df.price > 1000).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>price</th></tr></thead><tbody><tr><td>MacBook</td><td>1299</td></tr></tbody></table></div>
